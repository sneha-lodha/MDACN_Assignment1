# %%
import pandas as pd
import pathpy as pp
import pathpy.algorithms.statistics as stat
import pathpy.algorithms.shortest_paths as shorty
import numpy as np
import math as m
import matplotlib.pyplot as plt

# %%
df = pd.read_excel (r'manufacturing_emails_temporal_network.xlsx')

# %%
nodes = pd.concat([df["node1"], df["node2"]]).unique()
N = len(nodes)
print (len(nodes))

links = df[["node1","node2"]]
links = links.drop_duplicates()
L = links.shape[0]
# Out:
# 167

# %%
temporal = pp.TemporalNetwork()
for ind in df.index:
    temporal.add_edge(df['node1'][ind], df['node2'][ind], int(df['timestamp'][ind]))
print(temporal)
# Out:
# Nodes:			167
# Time-stamped links:	82876
# Links/Nodes:		496.2634730538922
# Observation period:	[1, 57791]
# Observation length:	 57790
# Time stamps:		 57791
# Avg. inter-event dt:	 1.0
# Min/Max inter-event dt:	 1/1

# %%
# edges = temporal.filter_edges(lambda v, w, time: time == 1)

edges = df[df['timestamp'] == 2]


print(edges.head(20))
# Out:
#     node1  node2  timestamp
# 16     18     19          2

# %%
def infect_graph(seed):
    end = 57792
    infected = {seed}
    stop_t = 0
    for t in range(1, end):
        edges = df[df['timestamp'] == t].to_numpy()
        new_infections = set()
        for e in edges:
            if(e[0] in infected):
                new_infections.add(e[1])
            elif(e[1] in infected):
                new_infections.add(e[0])
        infected.update(new_infections)
#       print(new_infections)

        
        if(len(infected)>=2):
            print(seed)
            print(f"Stopped at {t}")
            return t

        #if(len(infected)/N*100 > 75):
         #   print(seed)
          #  print(f"Stopped at {t}")
           # return t

ts = {}
its = 0
for i in nodes:
    its = its + 1
    print(its)
    ts[i] = infect_graph(i)

# infect_graph(4)

# df[df['timestamp'] == 1720].to_numpy()
# Out:
# 1
# 1
# Stopped at 1
# 2
# 18
# Stopped at 2
# 3
# 3
# Stopped at 1
# 4
# 20
# Stopped at 4
# 5
# 24
# Stopped at 8
# 6
# 26
# Stopped at 9
# 7
# 28
# Stopped at 10
# 8
# 29
# Stopped at 10
# 9
# 11
# Stopped at 1
# 10
# 21
# Stopped at 5
# 11
# 36
# Stopped at 20
# 12
# 13
# Stopped at 1
# 13
# 8
# Stopped at 1
# 14
# 4
# Stopped at 1
# 15
# 42
# Stopped at 27
# 16
# 47
# Stopped at 37
# 17
# 22
# Stopped at 6
# 18
# 17
# Stopped at 1
# 19
# 55
# Stopped at 52
# 20
# 50
# Stopped at 46
# 21
# 27
# Stopped at 9
# 22
# 19
# Stopped at 2
# 23
# 23
# Stopped at 7
# 24
# 2
# Stopped at 1
# 25
# 33
# Stopped at 14
# 26
# 62
# Stopped at 76
# 27
# 7
# Stopped at 1
# 28
# 5
# Stopped at 1
# 29
# 10
# Stopped at 1
# 30
# 15
# Stopped at 1
# 31
# 35
# Stopped at 19
# 32
# 12
# Stopped at 1
# 33
# 30
# Stopped at 12
# 34
# 6
# Stopped at 1
# 35
# 43
# Stopped at 27
# 36
# 48
# Stopped at 37
# 37
# 79
# Stopped at 134
# 38
# 38
# Stopped at 24
# 39
# 25
# Stopped at 8
# 40
# 14
# Stopped at 1
# 41
# 68
# Stopped at 81
# 42
# 84
# Stopped at 183
# 43
# 69
# Stopped at 81
# 44
# 76
# Stopped at 124
# 45
# 64
# Stopped at 76
# 46
# 57
# Stopped at 57
# 47
# 54
# Stopped at 49
# 48
# 32
# Stopped at 14
# 49
# 45
# Stopped at 32
# 50
# 71
# Stopped at 85
# 51
# 39
# Stopped at 25
# 52
# 66
# Stopped at 81
# 53
# 59
# Stopped at 63
# 54
# 34
# Stopped at 18
# 55
# 44
# Stopped at 31
# 56
# 9
# Stopped at 1
# 57
# 74
# Stopped at 85
# 58
# 65
# Stopped at 78
# 59
# 72
# Stopped at 85
# 60
# 61
# Stopped at 74
# 61
# 88
# Stopped at 226
# 62
# 63
# Stopped at 76
# 63
# 70
# Stopped at 82
# 64
# 40
# Stopped at 26
# 65
# 37
# Stopped at 20
# 66
# 93
# Stopped at 296
# 67
# 98
# Stopped at 373
# 68
# 56
# Stopped at 52
# 69
# 80
# Stopped at 139
# 70
# 53
# Stopped at 46
# 71
# 52
# Stopped at 46
# 72
# 83
# Stopped at 181
# 73
# 86
# Stopped at 186
# 74
# 103
# Stopped at 506
# 75
# 31
# Stopped at 14
# 76
# 104
# Stopped at 507
# 77
# 77
# Stopped at 131
# 78
# 75
# Stopped at 95
# 79
# 49
# Stopped at 41
# 80
# 92
# Stopped at 293
# 81
# 67
# Stopped at 81
# 82
# 82
# Stopped at 162
# 83
# 41
# Stopped at 26
# 84
# 81
# Stopped at 145
# 85
# 106
# Stopped at 579
# 86
# 85
# Stopped at 183
# 87
# 58
# Stopped at 59
# 88
# 46
# Stopped at 33
# 89
# 89
# Stopped at 226
# 90
# 16
# Stopped at 1
# 91
# 97
# Stopped at 362
# 92
# 122
# Stopped at 1559
# 93
# 146
# Stopped at 1798
# 94
# 60
# Stopped at 70
# 95
# 87
# Stopped at 221
# 96
# 94
# Stopped at 305
# 97
# 90
# Stopped at 226
# 98
# 73
# Stopped at 85
# 99
# 95
# Stopped at 329
# 100
# 101
# Stopped at 461
# 101
# 100
# Stopped at 421
# 102
# 112
# Stopped at 654
# 103
# 105
# Stopped at 573
# 104
# 107
# Stopped at 596
# 105
# 109
# Stopped at 596
# 106
# 121
# Stopped at 1316
# 107
# 51
# Stopped at 46
# 108
# 115
# Stopped at 799
# 109
# 108
# Stopped at 596
# 110
# 111
# Stopped at 596
# 111
# 99
# Stopped at 410
# 112
# 113
# Stopped at 738
# 113
# 102
# Stopped at 461
# 114
# 96
# Stopped at 330
# 115
# 110
# Stopped at 596
# 116
# 78
# Stopped at 132
# 117
# 91
# Stopped at 262
# 118
# 136
# Stopped at 1720
# 119
# 117
# Stopped at 852
# 120
# 114
# Stopped at 774
# 121
# 116
# Stopped at 834
# 122
# 118
# Stopped at 952
# 123
# 119
# Stopped at 1092
# 124
# 120
# Stopped at 1092
# 125
# 123
# Stopped at 1689
# 126
# 124
# Stopped at 1720
# 127
# 125
# Stopped at 1720
# 128
# 126
# Stopped at 1720
# 129
# 127
# Stopped at 1720
# 130
# 128
# Stopped at 1720
# 131
# 129
# Stopped at 1720
# 132
# 130
# Stopped at 1720
# 133
# 131
# Stopped at 1720
# 134
# 132
# Stopped at 1720
# 135
# 133
# Stopped at 1720
# 136
# 134
# Stopped at 1720
# 137
# 135
# Stopped at 1720
# 138
# 137
# Stopped at 1783
# 139
# 138
# Stopped at 1784
# 140
# 139
# Stopped at 1785
# 141
# 140
# Stopped at 1787
# 142
# 141
# Stopped at 1789
# 143
# 142
# Stopped at 1790
# 144
# 143
# Stopped at 1792
# 145
# 144
# Stopped at 1793
# 146
# 145
# Stopped at 1797
# 147
# 147
# Stopped at 1799
# 148
# 148
# Stopped at 1800
# 149
# 149
# Stopped at 4269
# 150
# 150
# Stopped at 5096
# 151
# 151
# Stopped at 6310
# 152
# 152
# Stopped at 14437
# 153
# 153
# Stopped at 15431
# 154
# 154
# Stopped at 24852
# 155
# 155
# Stopped at 24853
# 156
# 156
# Stopped at 24854
# 157
# 157
# Stopped at 24855
# 158
# 158
# Stopped at 24856
# 159
# 159
# Stopped at 27181
# 160
# 160
# Stopped at 27182
# 161
# 161
# Stopped at 27189
# 162
# 162
# Stopped at 27196
# 163
# 163
# Stopped at 27197
# 164
# 164
# Stopped at 30244
# 165
# 165
# Stopped at 30527
# 166
# 166
# Stopped at 31215
# 167
# 167
# Stopped at 55944

# %%
# sts = np.sort(list(ts.values()))
mapped_tsrank = [{"id": i, "t": tsrank[i]} for i in range(1, len(tsrank)+1)]
# bins = [ 200 + 10**x for x in np.arange(0,5, 0.2)]
# print( bins)
# plt.xscale('log')
# plt.hist([x["t"] for x in mapped_ts], bins = bins, density=True, log=True)
# print(mapped_ts)

# %%
net = pp.Network(directed=False)
np_links = links.to_numpy()
for l in np_links:
    net.add_edge(l[0], l[1])
print(net)
# Out:
# Undirected network
# Nodes:				167
# Links:				3250

# %%
agg_df = df.groupby(['node1', 'node2'], as_index=False).agg({"timestamp": "count"}).rename(columns={"timestamp": "weight"})

ds = []
ss = []

for n in nodes:
    edges = agg_df[np.logical_or(agg_df["node1"] == n, agg_df["node2"] == n)]
    ds.append({"id": n, "d": len(edges)})
    ss.append({"id": n, "s": edges["weight"].sum()})

# %%
def calcRecRate(f, ranks, metric):
    n = m.ceil(len(ranks)*f)
    ranks = set([x["id"] for x in ranks[:n]])
    metric = set([x["id"] for x in metric[:n]])
    intersect = ranks.intersection(metric)
#     print(ranks)
#     print(metric)
#     print(intersect)
    return len(intersect)/n
    

ss = sorted(ss, key = lambda x: x["s"], reverse=True)
ds = sorted(ds, key = lambda x: x["d"], reverse=True)
rs = sorted(mapped_ts, key= lambda x: x["t"])

xs = np.arange(0.05, 0.55, step = 0.05)
ys = []

for f in xs:
    ys.append(calcRecRate(f, rs, ds))

plt.plot(xs, ys)
plt.xlabel("f")
plt.ylabel("rRD(f)")


167*0.75
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <module>
#      12 ss = sorted(ss, key = lambda x: x["s"], reverse=True)
#      13 ds = sorted(ds, key = lambda x: x["d"], reverse=True)
# ---> 14 rs = sorted(mapped_ts, key= lambda x: x["t"])
#      16 xs = np.arange(0.05, 0.55, step = 0.05)
#      17 ys = []
#
# TypeError: '<' not supported between instances of 'NoneType' and 'int'

# %%
ys = []
for f in xs:
    ys.append(calcRecRate(f, rs, ss))
    
plt.xlabel("f")
plt.ylabel("rRS(f)")

plt.plot(xs, ys)

# %%
print (ts)
# Out:
# {1: 1, 18: 2, 3: 1, 20: 4, 24: 8, 26: 9, 28: 10, 29: 10, 11: 1, 21: 5, 36: 20, 13: 1, 8: 1, 4: 1, 42: 27, 47: 37, 22: 6, 17: 1, 55: 52, 50: 46, 27: 9, 19: 2, 23: 7, 2: 1, 33: 14, 62: 76, 7: 1, 5: 1, 10: 1, 15: 1, 35: 19, 12: 1, 30: 12, 6: 1, 43: 27, 48: 37, 79: 134, 38: 24, 25: 8, 14: 1, 68: 81, 84: 183, 69: 81, 76: 124, 64: 76, 57: 57, 54: 49, 32: 14, 45: 32, 71: 85, 39: 25, 66: 81, 59: 63, 34: 18, 44: 31, 9: 1, 74: 85, 65: 78, 72: 85, 61: 74, 88: 226, 63: 76, 70: 82, 40: 26, 37: 20, 93: 296, 98: 373, 56: 52, 80: 139, 53: 46, 52: 46, 83: 181, 86: 186, 103: 506, 31: 14, 104: 507, 77: 131, 75: 95, 49: 41, 92: 293, 67: 81, 82: 162, 41: 26, 81: 145, 106: 579, 85: 183, 58: 59, 46: 33, 89: 226, 16: 1, 97: 362, 122: 1559, 146: 1798, 60: 70, 87: 221, 94: 305, 90: 226, 73: 85, 95: 329, 101: 461, 100: 421, 112: 654, 105: 573, 107: 596, 109: 596, 121: 1316, 51: 46, 115: 799, 108: 596, 111: 596, 99: 410, 113: 738, 102: 461, 96: 330, 110: 596, 78: 132, 91: 262, 136: 1720, 117: 852, 114: 774, 116: 834, 118: 952, 119: 1092, 120: 1092, 123: 1689, 124: 1720, 125: 1720, 126: 1720, 127: 1720, 128: 1720, 129: 1720, 130: 1720, 131: 1720, 132: 1720, 133: 1720, 134: 1720, 135: 1720, 137: 1783, 138: 1784, 139: 1785, 140: 1787, 141: 1789, 142: 1790, 143: 1792, 144: 1793, 145: 1797, 147: 1799, 148: 1800, 149: 4269, 150: 5096, 151: 6310, 152: 14437, 153: 15431, 154: 24852, 155: 24853, 156: 24854, 157: 24855, 158: 24856, 159: 27181, 160: 27182, 161: 27189, 162: 27196, 163: 27197, 164: 30244, 165: 30527, 166: 31215, 167: 55944}

# %%
def infect_graph(seed):
    end = 57792
    infected = {seed}
    stop_t = 0
    for t in range(1, end):
        edges = df[df['timestamp'] == t].to_numpy()
        new_infections = set()
        for e in edges:
            if(e[0] in infected):
                new_infections.add(e[1])
            elif(e[1] in infected):
                new_infections.add(e[0])
        infected.update(new_infections)
#       print(new_infections)

        
        #if(len(infected)>=2):
         #   print(seed)
          #  print(f"Stopped at {t}")
           # return t

        if(len(infected)/N*100 > 75):
            print(seed)
            print(f"Stopped at {t}")
            return t

tsrank = {}
its = 0
for i in nodes:
    its = its + 1
    print(its)
    tsrank[i] = infect_graph(i)

# infect_graph(4)

# df[df['timestamp'] == 1720].to_numpy()
# Out:
# 1
# 1
# Stopped at 1720
# 2
# 18
# Stopped at 1720
# 3
# 3
# Stopped at 1720
# 4
# 20
# Stopped at 1720
# 5
# 24
# Stopped at 1720
# 6
# 26
# Stopped at 1720
# 7
# 28
# Stopped at 1720
# 8
# 29
# Stopped at 1720
# 9
# 11
# Stopped at 1720
# 10
# 21
# Stopped at 1720
# 11
# 36
# Stopped at 1720
# 12
# 13
# Stopped at 1720
# 13
# 8
# Stopped at 1720
# 14
# 4
# Stopped at 1720
# 15
# 42
# Stopped at 1720
# 16
# 47
# Stopped at 1720
# 17
# 22
# Stopped at 1720
# 18
# 17
# Stopped at 1720
# 19
# 55
# Stopped at 1720
# 20
# 50
# Stopped at 1720
# 21
# 27
# Stopped at 1720
# 22
# 19
# Stopped at 1720
# 23
# 23
# Stopped at 1720
# 24
# 2
# Stopped at 1720
# 25
# 33
# Stopped at 1720
# 26
# 62
# Stopped at 1720
# 27
# 7
# Stopped at 1720
# 28
# 5
# Stopped at 1720
# 29
# 10
# Stopped at 1720
# 30
# 15
# Stopped at 1720
# 31
# 35
# Stopped at 1720
# 32
# 12
# Stopped at 1720
# 33
# 30
# Stopped at 1720
# 34
# 6
# Stopped at 1720
# 35
# 43
# Stopped at 1720
# 36
# 48
# Stopped at 1720
# 37
# 79
# Stopped at 1720
# 38
# 38
# Stopped at 1720
# 39
# 25
# Stopped at 1720
# 40
# 14
# Stopped at 1720
# 41
# 68
# Stopped at 1720
# 42
# 84
# Stopped at 1720
# 43
# 69
# Stopped at 1720
# 44
# 76
# Stopped at 1720
# 45
# 64
# Stopped at 1720
# 46
# 57
# Stopped at 1720
# 47
# 54
# Stopped at 1720
# 48
# 32
# Stopped at 1720
# 49
# 45
# Stopped at 1720
# 50
# 71
# Stopped at 1720
# 51
# 39
# Stopped at 1720
# 52
# 66
# Stopped at 1720
# 53
# 59
# Stopped at 1720
# 54
# 34
# Stopped at 1720
# 55
# 44
# Stopped at 1720
# 56
# 9
# Stopped at 1720
# 57
# 74
# Stopped at 1720
# 58
# 65
# Stopped at 1720
# 59
# 72
# Stopped at 1720
# 60
# 61
# Stopped at 1720
# 61
# 88
# Stopped at 1720
# 62
# 63
# Stopped at 1720
# 63
# 70
# Stopped at 1720
# 64
# 40
# Stopped at 1720
# 65
# 37
# Stopped at 1720
# 66
# 93
# Stopped at 1720
# 67
# 98
# Stopped at 1720
# 68
# 56
# Stopped at 1720
# 69
# 80
# Stopped at 1720
# 70
# 53
# Stopped at 1720
# 71
# 52
# Stopped at 1720
# 72
# 83
# Stopped at 1720
# 73
# 86
# Stopped at 1720
# 74
# 103
# Stopped at 1720
# 75
# 31
# Stopped at 1720
# 76
# 104
# Stopped at 1720
# 77
# 77
# Stopped at 1720
# 78
# 75
# Stopped at 1720
# 79
# 49
# Stopped at 1720
# 80
# 92
# Stopped at 1720
# 81
# 67
# Stopped at 1720
# 82
# 82
# Stopped at 1720
# 83
# 41
# Stopped at 1720
# 84
# 81
# Stopped at 1720
# 85
# 106
# Stopped at 1720
# 86
# 85
# Stopped at 1720
# 87
# 58
# Stopped at 1720
# 88
# 46
# Stopped at 1720
# 89
# 89
# Stopped at 1720
# 90
# 16
# Stopped at 1720
# 91
# 97
# Stopped at 1720
# 92
# 122
# Stopped at 2536
# 93
# 146
# Stopped at 2536
# 94
# 60
# Stopped at 1720
# 95
# 87
# Stopped at 1720
# 96
# 94
# Stopped at 1720
# 97
# 90
# Stopped at 1720
# 98
# 73
# Stopped at 1720
# 99
# 95
# Stopped at 1720
# 100
# 101
# Stopped at 1720
# 101
# 100
# Stopped at 1720
# 102
# 112
# Stopped at 1720
# 103
# 105
# Stopped at 1720
# 104
# 107
# Stopped at 1720
# 105
# 109
# Stopped at 1720
# 106
# 121
# Stopped at 1720
# 107
# 51
# Stopped at 1720
# 108
# 115
# Stopped at 1720
# 109
# 108
# Stopped at 1720
# 110
# 111
# Stopped at 1720
# 111
# 99
# Stopped at 1720
# 112
# 113
# Stopped at 1720
# 113
# 102
# Stopped at 1720
# 114
# 96
# Stopped at 1720
# 115
# 110
# Stopped at 1720
# 116
# 78
# Stopped at 1720
# 117
# 91
# Stopped at 1720
# 118
# 136
# Stopped at 2536
# 119
# 117
# Stopped at 1720
# 120
# 114
# Stopped at 2536
# 121
# 116
# Stopped at 1720
# 122
# 118
# Stopped at 1720
# 123
# 119
# Stopped at 1720
# 124
# 120
# Stopped at 1720
# 125
# 123
# Stopped at 2536
# 126
# 124
# Stopped at 2536
# 127
# 125
# Stopped at 2536
# 128
# 126
# Stopped at 2536
# 129
# 127
# Stopped at 2536
# 130
# 128
# Stopped at 2536
# 131
# 129
# Stopped at 2536
# 132
# 130
# Stopped at 2536
# 133
# 131
# Stopped at 2536
# 134
# 132
# Stopped at 2536
# 135
# 133
# Stopped at 2536
# 136
# 134
# Stopped at 2536
# 137
# 135
# Stopped at 2536
# 138
# 137
# Stopped at 4067
# 139
# 138
# Stopped at 2536
# 140
# 139
# Stopped at 2536
# 141
# 140
# Stopped at 2536
# 142
# 141
# Stopped at 2536
# 143
# 142
# Stopped at 2536
# 144
# 143
# Stopped at 2536
# 145
# 144
# Stopped at 4067
# 146
# 145
# Stopped at 2536
# 147
# 147
# Stopped at 2536
# 148
# 148
# Stopped at 2536
# 149
# 149
# Stopped at 4359
# 150
# 150
# Stopped at 6308
# 151
# 151
# Stopped at 6706
# 152
# 152
# Stopped at 15785
# 153
# 153
# Stopped at 17409
# 154
# 154
# Stopped at 26709
# 155
# 155
# Stopped at 56143
# 156
# 156
# Stopped at 26709
# 157
# 157
# Stopped at 26709
# 158
# 158
# Stopped at 26709
# 159
# 159
# Stopped at 30084
# 160
# 160
# Stopped at 29498
# 161
# 161
# Stopped at 29498
# 162
# 162
# Stopped at 29498
# 163
# 163
# Stopped at 30527
# 164
# 164
# Stopped at 33385
# 165
# 165
# Stopped at 33395
# 166
# 166
# Stopped at 35037
# 167
# 167
# Stopped at 57603

# %%
def calcRecRate(f, ranks, metric):
    n = m.ceil(len(ranks)*f)
    ranks = set([x["id"] for x in ranks[:n]])
    metric = set([x["id"] for x in metric[:n]])
    intersect = ranks.intersection(metric)
#     print(ranks)
#     print(metric)
#     print(intersect)
    return len(intersect)/n

mapped_tsrank = [{"id": i, "t": tsrank[i]} for i in range(1, len(tsrank)+1)]
mapped_ts = [{"id": i, "t": ts[i]} for i in range(1, len(ts)+1)]



rsrank = sorted(mapped_tsrank, key= lambda x: x["t"])
rs = sorted(mapped_ts, key= lambda x: x["t"])


xs = np.arange(0.05, 0.55, step = 0.05)
ys = []

for f in xs:
    ys.append(calcRecRate(f, rs, rsrank))


plt.plot(xs, ys)
plt.xlabel("f")
plt.ylabel("rRZ(f)")
# Out:
# Text(0, 0.5, 'rRZ(f)')
